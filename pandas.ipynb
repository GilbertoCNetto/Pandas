# %% [markdown]
# <a href="https://colab.research.google.com/github/GilbertoCNetto/Pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Leia um arquivo csv e armazene em um dataframe Pandas;

import pandas as pd
dataset = pd.read_csv('./imdb.csv')

# %%
# Exiba este dataframe completo;
dataset_df = pd.DataFrame(dataset)
display(dataset_df)
# Out:
#     lister-item-index       lister-item-header certificate runtime  \
# 0                 1.0          Stranger Things          15  60 min
# 1                 2.0           13 Reasons Why          18  60 min
# 2                 3.0  Orange Is the New Black          18  59 min
# 3                 4.0             Black Mirror          18  60 min
# 4                 5.0              Money Heist          15  60 min
# ..                ...                      ...         ...     ...
# 75               76.0          F Is for Family          15  30 min
# 76               77.0                The Ranch          15  30 min
# 77               78.0          American Vandal          15  34 min
# 78               79.0               Dead to Me          15  30 min
# 79               80.0                Quicksand          18  45 min
#
#                        genre  rating      votes
# 0     Drama, Fantasy, Horror     8.7  1,327,188
# 1   Drama, Mystery, Thriller     7.5    314,321
# ...

# %%
# Mostre as 5 primeiras linhas e as 5 ultimas linhas do dataframe;
display(dataset_df.head(5))
display(dataset_df.tail(5))
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
# 3                4.0             Black Mirror          18  60 min
# 4                5.0              Money Heist          15  60 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2      Comedy, Crime, Drama     8.0    319,342
# 3    Drama, Mystery, Sci-Fi     8.7    636,319
# 4      Action, Crime, Drama     8.2    529,086
#     lister-item-index lister-item-header certificate runtime  \
# 75               76.0    F Is for Family          15  30 min
# 76               77.0          The Ranch          15  30 min
# 77               78.0    American Vandal          15  34 min
# ...

# %%
# Mostre a transposta deste dataframe
dataset_df.T
# Out:
#                                         0                         1   \
# lister-item-index                      1.0                       2.0
# lister-item-header         Stranger Things            13 Reasons Why
# certificate                             15                        18
# runtime                             60 min                    60 min
# genre               Drama, Fantasy, Horror  Drama, Mystery, Thriller
# rating                                 8.7                       7.5
# votes                            1,327,188                   314,321
#
#                                          2                       3   \
# lister-item-index                       3.0                     4.0
# lister-item-header  Orange Is the New Black            Black Mirror
# certificate                              18                      18
# runtime                              59 min                  60 min
# genre                  Comedy, Crime, Drama  Drama, Mystery, Sci-Fi
# ...

# %%
# Mostre os valores de uma única coluna e também a quantidade que cada valor aparece;
display(dataset_df['rating'].unique())
display(dataset_df['rating'].value_counts())
# Out:
# array([8.7, 7.5, 8. , 8.2, 8.1, 8.8, 8.6, 7.9, 8.3, 7.2, 7.7, 7.4, 7.8,
#        8.4, 6.4, 6.3, 6.5, 7.3, 7. , 8.5, 6.8, 7.6, 7.1, 6.6, 6.7, 5.9,
#        6.9])
# rating
# 8.2    7
# 8.0    6
# 8.6    5
# 7.2    5
# 8.7    4
# 7.8    4
# 6.7    4
# 8.5    4
# 7.9    4
# 7.7    4
# 7.5    4
# 6.4    3
# 8.4    3
# 7.4    3
# 8.3    2
# 7.3    2
# 7.0    2
# 8.8    2
# 7.6    2
# 7.1    2
# 8.1    2
# 6.3    1
# 6.5    1
# 6.8    1
# 6.6    1
# 5.9    1
# 6.9    1
# Name: count, dtype: int64

# %%
# Mostre o dataframe agrupado por uma coluna escolhida;
df_agrupado = dataset_df.groupby('votes').agg('sum').sort_values('lister-item-index')
display(df_agrupado)
# Out:
#           lister-item-index       lister-item-header certificate runtime  \
# votes
# 1,327,188                 0          Stranger Things          15  60 min
# 319,342                   0  Orange Is the New Black          18  59 min
# 636,319                   0             Black Mirror          18  60 min
# 314,321                 2.0           13 Reasons Why          18  60 min
# 529,086                 5.0              Money Heist          15  60 min
# ...                     ...                      ...         ...     ...
# 41,074                 76.0          F Is for Family          15  30 min
# 42,401                 77.0                The Ranch          15  30 min
# 32,985                 78.0          American Vandal          15  34 min
# 99,440                 79.0               Dead to Me          15  30 min
# 25,507                 80.0                Quicksand          18  45 min
#
#                               genre  rating
# votes
# ...

# %%
# Selecione uma coluna e dentro desta três valores específicos para trocar por um NaN;

# Exibindo o DataFrame original
print("DATAFRAME ORIGINAL:")
display(dataset)

# Selecionando a coluna e substituindo valores específicos por NaN
values_to_replace = [1.0, 3.0, 5.0]
column_name = 'lister-item-index'
dataset_alterado = dataset_df
dataset_alterado[column_name] = dataset_df[column_name].replace(values_to_replace, pd.NA)

# Exibindo o DataFrame com os valores substituídos
print("\nDATA FRAME COM VALORES ALTERADOS:")
display(dataset_alterado)
# Out:
# DATAFRAME ORIGINAL:
#     lister-item-index       lister-item-header certificate runtime  \
# 0                 1.0          Stranger Things          15  60 min
# 1                 2.0           13 Reasons Why          18  60 min
# 2                 3.0  Orange Is the New Black          18  59 min
# 3                 4.0             Black Mirror          18  60 min
# 4                 5.0              Money Heist          15  60 min
# ..                ...                      ...         ...     ...
# 75               76.0          F Is for Family          15  30 min
# 76               77.0                The Ranch          15  30 min
# 77               78.0          American Vandal          15  34 min
# 78               79.0               Dead to Me          15  30 min
# 79               80.0                Quicksand          18  45 min
#
#                        genre  rating      votes
# 0     Drama, Fantasy, Horror     8.7  1,327,188
# ...

# %%
# Mostre o dataframe sem os registros que possuem NaN;

# Exibindo o DataFrame Alterado
print("DataFrame Alterado:")
display(dataset_alterado)

# Removendo os registros que possuem valor NaN
dataset_clean = dataset_alterado.dropna()

# Exibindo o DataFrame com os registros que possuem NaN
print("\nDataFrame sem registros NaN:")
display(dataset_clean)
# Out:
# DataFrame Alterado:
#    lister-item-index       lister-item-header certificate runtime  \
# 0               <NA>          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2               <NA>  Orange Is the New Black          18  59 min
# 3                4.0             Black Mirror          18  60 min
# 4               <NA>              Money Heist          15  60 min
# ..               ...                      ...         ...     ...
# 75              76.0          F Is for Family          15  30 min
# 76              77.0                The Ranch          15  30 min
# 77              78.0          American Vandal          15  34 min
# 78              79.0               Dead to Me          15  30 min
# 79              80.0                Quicksand          18  45 min
#
#                        genre  rating      votes
# 0     Drama, Fantasy, Horror     8.7  1,327,188
# 1   Drama, Mystery, Thriller     7.5    314,321
# ...

# %%
# Mostre os valores estatísticos do dataframe;

# Selecionando as colunas desejadas
selected_columns = ['runtime', 'votes']
selected_data = dataset[selected_columns]
another_columns = ['lister-item-index', 'rating']
selected_data2 = dataset[another_columns]
# Exibindo os valores estatísticos das colunas selecionadas
print("Valores estatísticos das colunas selecionadas:")
display(selected_data.describe())
display(selected_data2.describe())
# Out:
# Valores estatísticos das colunas selecionadas:
#        runtime      votes
# count       80         80
# unique      27         80
# top     60 min  1,327,188
# freq        25          1
#        lister-item-index    rating
# count            80.0000  80.00000
# mean             40.5000   7.72000
# std              23.2379   0.71235
# min               1.0000   5.90000
# 25%              20.7500   7.20000
# 50%              40.5000   7.80000
# 75%              60.2500   8.22500
# max              80.0000   8.80000

# %%
# Crie os seguintes gráficos baseados no dataframe: histograma, dispersão e colunas

import matplotlib.pyplot as plt

# Histograma
plt.figure(figsize=(8, 6))
plt.hist(dataset['rating'], bins=10, color='aquamarine', edgecolor='black')
plt.title('Distribuição de Notas x Frequências')
plt.xlabel('Notas')
plt.ylabel('Frequência')
# Frequência é o número de vezes que aquele "Rating"(nota) aparece
plt.grid(False)
plt.show()

# Gráfico de dispersão (Notas vs. Posição)
plt.figure(figsize=(8, 6))
plt.scatter(dataset.head(20)['rating'], dataset.head(20)['lister-item-index'], color='dodgerblue', alpha=1)
plt.title('Notas vs. Posição: Melhores 20 Séries')
plt.xlabel('Notas')
plt.ylabel('Posição')
plt.gca().invert_yaxis()
plt.grid(True)
plt.show()

# Gráfico de barras para a posição
plt.figure(figsize=(8, 6))
plt.bar(dataset.head(15)['lister-item-index'], dataset.head(15)['rating'], color='crimson', alpha=1)
plt.title('Notas por Posição')
plt.xlabel('Posição')
plt.ylabel('Notas')
plt.yticks(range(1, 11))
plt.xticks(dataset.head(15)['lister-item-index'])
plt.grid(axis='y')
plt.show()
